# %%
# !pip install backtesting
# !pip install matplotlib
# Out:
# Requirement already satisfied: backtesting in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.6.5)
# Requirement already satisfied: numpy>=1.17.0 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from backtesting) (2.4.3)
# Requirement already satisfied: pandas!=0.25.0,>=0.25.0 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from backtesting) (2.3.3)
# Requirement already satisfied: bokeh!=3.0.*,!=3.2.*,>=3.0.0 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from backtesting) (3.9.0)
# Requirement already satisfied: Jinja2>=2.9 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (2.18.0)
# Requirement already satisfied: packaging>=16.8 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (26.0)
# Requirement already satisfied: pillow>=7.1.0 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (12.1.1)
# Requirement already satisfied: PyYAML>=3.10 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (6.5.5)
# Requirement already satisfied: xyzservices>=2021.09.1 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (2026.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from Jinja2>=2.9->bokeh!=3.0.*,!=3.2.*,>=3.0.0->backtesting) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas!=0.25.0,>=0.25.0->backtesting) (1.17.0)
# Requirement already satisfied: matplotlib in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from backtesting import Strategy
from backtesting import Backtest
import asyncio
from datetime import datetime, timedelta
import nest_asyncio


import sys
from pathlib import Path

# Добавляем корень проекта в путь импортов
# Предположим, ноутбук лежит в notebooks/, а проект — на уровень выше
project_root = r"C:\Users\Khanin Maksim\PycharmProjects\honeyProject\docker\data_loader"
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Теперь импорты работают
from metrics.builtins.python_metrics import *
from T_con import TConnector
from constants import TIMEFRAMES
# Out:
# C:\Users\Khanin Maksim\AppData\Local\Programs\Python\Python312\Lib\site-packages\backtesting\_plotting.py:55: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support, such as old IDEs. Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d9d2ffc0-e341-4d8a-a079-9c25f8779963">Loading BokehJS ...</span>
#     </div>

# %%
# ===== Ячейка 1: Импорты и настройка =====


nest_asyncio.apply()  # Критично для asyncio в Jupyter!

# Твои параметры
TOKEN = 't.YS2uyKoFJ_BjA2Jz2CLNsRrpEWL5e7ad4Mq48OKNUySiNbs2QrGhIcW4gkj4-MTl62oO1quiZK8GPLkd6OM7Dw' # 🔐 Храни в .env, не коммить!
TICKER = "SBER"
TIMEFRAME = "1d"  # Для 4 лет лучше дневки, иначе получишь 4*252*6.5*12 = ~75k свечей для 1h
YEARS = 4

# ===== Ячейка 2: Функция-обёртка для загрузки =====
async def fetch_candles_to_df(
    connector: TConnector,
    ticker: str,
    timeframe: str,
    years: int = 1
) -> pd.DataFrame:
    """
    Загружает исторические свечи и возвращает pandas DataFrame.
    """
    # 1. Получаем UID инструмента
    uid = await connector.get_instrument_uid(ticker)
    if not uid:
        raise ValueError(f"❌ Тикер {ticker} не найден")

    # 2. Рассчитываем диапазон дат
    #to_date = datetime.now()
    #from_date = to_date - timedelta(days=years * 365)

    # 3. Загружаем данные (твой метод уже умеет чанковать)
    candles = await connector.load_historical_data(
        ticker="SBER",
        uid=uid,
        timeframe="1d",
        history_depth_days=years * 365  # ~1460 дней
    )

    # 4. Конвертируем в DataFrame
    if not candles:
        return pd.DataFrame()

    df = pd.DataFrame(candles)
    df['time'] = pd.to_datetime(df['time'])
    df = df.set_index('time').sort_index()

    # 5. Добавляем метаданные
    df.attrs['ticker'] = ticker
    df.attrs['timeframe'] = timeframe

    return df

def calculate_metric_series(candles_df: pd.DataFrame, metric_class, window: int = 50) -> pd.Series:
    """
    Прогоняет метрику по всей истории, возвращает Series с индексом = time.
    Не ломает твой pure-Python код, использует pandas только для обёртки.
    """
    metric = metric_class()
    results = []

    window = metric.min_candles

    # candles_df должен быть отсортирован по time
    candles_list = candles_df[['open','high','low','close']].to_dict('records')

    for i in range(len(candles_list)):
        window_data = candles_list[max(0, i - window): i + 1]
        if len(window_data) < metric.min_candles:
            results.append(None)
            continue
        res = metric.calculate_python(window_data)
        # Берём первое значение из dict (у тебя обычно 1-2 ключа)
        val = next(iter(res.values()), None)
        results.append(val)

    return pd.Series(results, index=candles_df.index, name=metric.name)

# %%
# ===== Ячейка 3: Запуск =====
# Создаём коннектор
connector = TConnector(token=TOKEN, log_level="INFO")

# Загружаем данные
df_raw = await fetch_candles_to_df(
    connector=connector,
    ticker="SBER",
    timeframe="1d",  # Дневки: ~1000 строк за 4 года — идеально для бэктеста
    years=5
)

# Смотрим результат
#print(f"✅ Загружено {len(df)} свечей")
#print(df.head())
#print(df.tail())

# Быстрая визуализация
#df['close'].plot(title=f"{TICKER} Close Price", figsize=(12, 4), grid=True)
# Out:
# 2026-04-10 15:23:36,794 | INFO | TConnector | ✅ TConnector инициализирован. Готов сосать... то есть, работать с Tinkoff API.
# 2026-04-10 15:23:36,798 | INFO | TConnector | 🔄 Принудительное обновление кэша...
# 2026-04-10 15:23:36,799 | INFO | TConnector | 📦 Загрузка реестра инструментов из Tinkoff API...
# 2026-04-10 15:23:40,774 | INFO | TConnector | Загрузка индикативов...
# 2026-04-10 15:23:40,829 | INFO | TConnector | Индикативы: 73 инструментов
# 2026-04-10 15:23:40,831 | INFO | TConnector | ✅ Всего загружено: 4181 инструментов
# 2026-04-10 15:23:40,834 | INFO | TConnector | ✅ Кэш обновлен: 4177 инструментов
# 2026-04-10 15:23:40,836 | INFO | TConnector | ✅ Найден UID для SBER: e6123145-9665-43e0-8413-cd61b8aa9b13
# 2026-04-10 15:23:40,837 | INFO | TConnector | 🆕 Полная загрузка: глубина 1825 дн. (параметр)
# 2026-04-10 15:23:40,994 | INFO | TConnector | 📥 Кусок [04-11 15:23 - 04-11 15:23]: 238 свечей. Всего: 238
# 2026-04-10 15:23:41,298 | INFO | TConnector | 📥 Кусок [04-11 15:23 - 04-11 15:23]: 253 свечей. Всего: 491
# 2026-04-10 15:23:41,599 | INFO | TConnector | 📥 Кусок [04-11 15:23 - 04-10 15:23]: 255 свечей. Всего: 746
# 2026-04-10 15:23:41,956 | INFO | TConnector | 📥 Кусок [04-10 15:23 - 04-10 15:23]: 265 свечей. Всего: 1011
# 2026-04-10 15:23:42,274 | INFO | TConnector | 📥 Кусок [04-10 15:23 - 04-10 15:23]: 329 свечей. Всего: 1340
# 2026-04-10 15:23:42,478 | INFO | TConnector | ✅ Загрузка для SBER завершена. Всего: 1340 свечей

# %%
from metrics.builtins.python_metrics import ZScoreMetric
from metrics.builtins.python_metrics import SkewKurtosisMetric


df = df_raw.copy()


# 2. Считаешь метрики разово (pandas тут разрешён, ядро не трогаем)
df['skew_oc_50'] = calculate_metric_series(df, SkewKurtosisMetric)
df['kurt_excess_oc_50'] = calculate_metric_series(df, SkewKurtosisMetric)  # или отдельный класс
df['zscore_20'] = calculate_metric_series(df, ZScoreMetric)

df = df.rename(columns={
    'open': 'Open',
    'high': 'High',
    'low': 'Low',
    'close': 'Close',
    'volume': 'Volume'
})

# 3. Отбрасываем NaN от warmup
df = df.dropna(subset=['skew_oc_50', 'kurt_excess_oc_50', 'zscore_20'])

# %%
print(df)
# Out:
#               Open    High     Low   Close    Volume
# time
# 2021-04-12  278.20  285.35  278.00  281.20  57180030
# 2021-04-13  282.93  288.20  281.14  286.28  67973520
# 2021-04-14  290.00  291.58  286.72  288.30  59364940
# 2021-04-15  281.50  285.19  280.87  283.17  88048600
# 2021-04-16  285.71  289.30  284.08  289.03  63499000
# ...            ...     ...     ...     ...       ...
# 2026-04-06  315.04  319.75  314.60  318.98  35505681
# 2026-04-07  319.28  320.81  317.66  317.87  23014285
# 2026-04-08  319.50  321.18  318.40  319.40  18211595
# 2026-04-09  319.75  320.86  316.00  317.51  31890826
# 2026-04-10  317.98  318.79  316.57  318.20  10014592
#
# [1340 rows x 5 columns]

# %%
class StatArbStrategy(Strategy):
    # Параметры оптимизации
    skew_threshold = -0.5
    kurt_threshold = 3.0
    zscore_entry = 2.0

    def init(self):
        # Подключаем заранее рассчитанные метрики как колонки
        self.skew = self.data.skew_oc_50
        self.kurt = self.data.kurt_excess_oc_50
        self.zscore = self.data.zscore_20

    def next(self):
        # self.data[] работает как pandas Series
        if self.skew[-1] is None or self.kurt[-1] is None:
            return  # Период разогрева (warmup)

        # Режим: не лезем, если хвосты жирные и асимметрия левая
        if self.kurt[-1] > self.kurt_threshold and self.skew[-1] < self.skew_threshold:
            if self.position.is_long:
                self.position.close()
            return

        # Вход по возврату к среднему
        if self.zscore[-1] < -self.zscore_entry and not self.position:
            self.buy(sl=0.98)  # Пример
        elif self.zscore[-1] > self.zscore_entry and not self.position:
            self.sell(sl=1.02)

# %%
# 4. Запускаешь бэктест
bt = Backtest(df, StatArbStrategy, cash=100_000, commission=0.0015)
stats = bt.run()
bt.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       1 # 4. Запускаешь бэктест
#       2 bt = Backtest(df, StatArbStrategy, cash=100_000, commission=0.0015)
#       3 stats = bt.run()
# ----> 4 bt.plot(plot_width=800, plot_height=400, filename=None, open_browser=False)
#
# TypeError: Backtest.plot() got an unexpected keyword argument 'plot_height'
